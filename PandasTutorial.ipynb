# %% [markdown]
# # Pandas Tutorial
#
# This tutorial is based on Keith Galli's YouTube tutorial:

# %%
# %%html
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/2uvysYbKdjM?si=zmBEgxTFtEz7-6Mb" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/2uvysYbKdjM?si=zmBEgxTFtEz7-6Mb" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## The DataFrame
#
# The DataFrame is the core structure of pandas and in essence is a table of the inputted values.

# %%
import pandas as pd

# Create the table with columns named A, B, C and rows named X, Y, Z

df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A', 'B', 'C'], index=['X','Y','Z'])

# %% [markdown]
# The .info() function gives the information of the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %% [markdown]
# The .shape property gives the size of the DataFrame.

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# The .size property gives the total number of values in a DataFrame.

# %%
df.size
# Out:
# 9

# %% [markdown]
# The .index property outputs a list of the row names in the DataFrame.

# %%
df.index
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %% [markdown]
# The .head() function gives the first 5 rows in a DataFrame, unless a numerical argument is passed in which case the first  of that many rows is given.

# %%
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %% [markdown]
# The .tail() function gives the last 5 rows in a DataFrame, unless a numerical argument is passed in which case the last of that many rows is given.

# %%
df.tail()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %% [markdown]
# The .sample() function gives a random row in a DataFrame, unless a numerical argument is passed in which case that many random rows are given.

# %%
df.sample()
# Out:
#    A  B  C
# Y  4  5  6

# %% [markdown]
# The .describe() function performs descriptive statistics on the columns in the DataFrame.

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %% [markdown]
# The .nunique() function gives the number of unique values in a DataFrame.

# %%
# Number of unique values in each column
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
# Number of unique values in a specified column
df['A'].nunique()
# Out:
# 3

# %% [markdown]
# The .unique() function gives a list of the unique values in a column.

# %%
df['A'].unique()
# Out:
# array([1, 4, 7], dtype=int64)

# %% [markdown]
# A copy of the DataFrame can be made using the `.copy()` function.

# %%
# Create a new, separate DataFrame from the original
df_new = df.copy()

# Create a new pointer to an already existing DataFrame (i.e. what changes you make to the original DataFrame will also appear in this one)
df_pointer = df

# %% [markdown]
# ## Loading a DataFrame from a File

# %% [markdown]
# The `.read_...()` function is used to read .csv, .xlsx, .parquet and .feather files into a DataFrame. The time it takes to parse a file depends on the file format as well as the data.

# %%
# %%time
# Read .feather files
resultsFeather = pd.read_feather('./data/results.feather')
# Out:
# CPU times: total: 281 ms
# Wall time: 289 ms

# %%
# %%time
# Read .parquet files
resultsParquet = pd.read_parquet('./data/results.parquet')
# Out:
# CPU times: total: 734 ms
# Wall time: 415 ms

# %%
# %%time
# Read .csv files
resultsCSV = pd.read_csv('./data/results.csv')
# Out:
# CPU times: total: 1.48 s
# Wall time: 1.49 s

# %%
# %%time
# Read .xlsx files
olympicDataExcel = pd.read_excel('./data/olympics-data.xlsx')
# Out:
# CPU times: total: 1min 16s
# Wall time: 1min 20s

# %% [markdown]
# ## Saving a DataFrame to a File

# %% [markdown]
# The `.to_...()` function is used to save DataFrames to a .csv, .xlsx, .parquet or .feather file.

# %%
# Save to .csv file
resultsCSV.to_csv('./data/resultsv2.csv')

# Save to .csv file without index column
resultsCSV.to_csv('./data/resultsv2noindex.csv', index=False)

# %% [markdown]
# ## Accessing Data

# %% [markdown]
# ### Columns
#
# Columns of a DataFrame can be given depending on the column name.

# %%
# The . syntax can be used if the column name is without spaces
resultsCSV.year
# Out:
# 0         1912.0
# 1         1912.0
# 2         1920.0
# 3         1920.0
# 4         1920.0
#            ...
# 308403    2022.0
# 308404    2022.0
# 308405    2022.0
# 308406    2022.0
# 308407    2022.0
# Name: year, Length: 308408, dtype: float64

# %%
# The locater syntax [] must be used if the column name has a space
resultsCSV['year']
# Out:
# 0         1912.0
# 1         1912.0
# 2         1920.0
# 3         1920.0
# 4         1920.0
#            ...
# 308403    2022.0
# 308404    2022.0
# 308405    2022.0
# 308406    2022.0
# 308407    2022.0
# Name: year, Length: 308408, dtype: float64

# %% [markdown]
# ### Single Values
#
# The `.at()` parameter is used to give a single data point in a DataFrame using the column name.

# %%
resultsCSV.at[0, 'year']
# Out:
# 1912.0

# %% [markdown]
# The `.iat[]` parameter is used to give a single data point in a DataFrame using the column index.

# %%
resultsCSV.iat[0, 2]
# Out:
# 'Tennis'

# %% [markdown]
# ### Multiple Values
#
# The `.loc[rows, columns]` parameter is used to find data in a DataFrame using the column names.

# %%
# Give all rows
resultsCSV.loc[0:]
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA              NaN   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA              NaN   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 308403          Marián Skupek      148983  SVK              NaN   26.0  False
# 308404          Elsa Fermbäck      148984  SWE              NaN   28.0  False
# 308405          Hilma Lövblom      148985  SWE           Sweden   13.0  False
# 308406          Hilma Lövblom      148985  SWE              NaN    NaN  False
# 308407   Charlotta Säfvenberg      148986  NaN              NaN   24.0  False
#
#        medal
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 308403   NaN
# 308404   NaN
# 308405   NaN
# 308406   NaN
# 308407   NaN
#
# [308408 rows x 11 columns]

# %%
# Give the 0 row
resultsCSV.loc[0]
# Out:
# year                          1912.0
# type                          Summer
# discipline                    Tennis
# event         Singles, Men (Olympic)
# as             Jean-François Blanchy
# athlete_id                         1
# noc                              FRA
# team                             NaN
# place                           17.0
# tied                            True
# medal                            NaN
# Name: 0, dtype: object

# %%
# Give the 0, 10 and 15 rows
resultsCSV.loc[[0, 10, 15]]
# Out:
#       year    type discipline                   event                     as  \
# 0   1912.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
# 10  1920.0  Summer     Tennis  Singles, Men (Olympic)        Jacques Brugnon
# 15  1912.0  Summer     Tennis  Doubles, Men (Olympic)           Albert Canet
#
#     athlete_id  noc                      team  place   tied   medal
# 0            1  FRA                       NaN   17.0   True     NaN
# 10           4  FRA                       NaN    9.0   True     NaN
# 15           5  FRA  Édouard Mény de Marangue    3.0  False  Bronze

# %%
# Give the 5 to 10 rows
resultsCSV.loc[5:10]
# Out:
#       year    type discipline                     event               as  \
# 5   1996.0  Summer     Tennis    Singles, Men (Olympic)   Arnaud Boetsch
# 6   1996.0  Summer     Tennis    Doubles, Men (Olympic)   Arnaud Boetsch
# 7   1924.0  Summer     Tennis    Singles, Men (Olympic)     Jean Borotra
# 8   1924.0  Summer     Tennis  Doubles, Mixed (Olympic)     Jean Borotra
# 9   1924.0  Summer     Tennis    Doubles, Men (Olympic)     Jean Borotra
# 10  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jacques Brugnon
#
#     athlete_id  noc                team  place   tied   medal
# 5            2  FRA                 NaN   17.0   True     NaN
# 6            2  FRA     Guillaume Raoux   17.0   True     NaN
# 7            3  FRA                 NaN    4.0  False     NaN
# 8            3  FRA  Marguerite Billout   15.0   True     NaN
# 9            3  FRA        René Lacoste    3.0  False  Bronze
# 10           4  FRA                 NaN    9.0   True     NaN

# %%
# Give the values in the 6 row and the event, as columns
resultsCSV.loc[6, ['event', 'as']]
# Out:
# event    Doubles, Men (Olympic)
# as               Arnaud Boetsch
# Name: 6, dtype: object

# %% [markdown]
# The `.iloc[rows, columns]` parameter is used to find data in a DataFrame using the column indexes.

# %%
resultsCSV.iloc[0:3, 1:3]
# Out:
#      type discipline
# 0  Summer     Tennis
# 1  Summer     Tennis
# 2  Summer     Tennis

# %% [markdown]
# ## Sorting Data

# %% [markdown]
# The `.sort_values([columns], ascending=[True/False])` function is used to sort data in a table in order of the columns provided.

# %%
# Sorts by year in ascending order
resultsCSV.sort_values('year')
# Out:
#           year    type           discipline  \
# 148611  1896.0  Summer            Athletics
# 147979  1896.0  Summer            Athletics
# 163701  1896.0  Summer            Athletics
# 163700  1896.0  Summer            Athletics
# 163699  1896.0  Summer            Athletics
# ...        ...     ...                  ...
# 203177     NaN     NaN              Fencing
# 203178     NaN     NaN              Fencing
# 217586     NaN     NaN  Football (Football)
# 217587     NaN     NaN  Football (Football)
# 271490     NaN     NaN    Diving (Aquatics)
#
#                                     event                    as  athlete_id  \
# 148611          100 metres, Men (Olympic)           Nándor Dáni       71127
# 147979            Shot Put, Men (Olympic)  Georgios Papasideris       70824
# 163701           Long Jump, Men (Olympic)            Tom Curtis       78290
# 163700  110 metres Hurdles, Men (Olympic)            Tom Curtis       78290
# 163699          100 metres, Men (Olympic)            Tom Curtis       78290
# ...                                   ...                   ...         ...
# 203177   Sabre, Individual, Men (Olympic)       Lóránt Mészáros       95189
# 203178         Sabre, Team, Men (Olympic)       Lóránt Mészáros       95189
# 217586       Football, Men (Intercalated)       Georgios Pantos      100811
# 217587       Football, Men (Intercalated)  Alexandros Kalafatis      100812
# 271490       Platform, Men (Intercalated)      Wilhelm Lindgren      127259
#
#         noc     team  place   tied   medal
# 148611  HUN      NaN    NaN  False     NaN
# 147979  GRE      NaN    3.0  False  Bronze
# 163701  USA      NaN    NaN  False     NaN
# 163700  USA      NaN    1.0  False    Gold
# 163699  USA      NaN    1.0  False     NaN
# ...     ...      ...    ...    ...     ...
# 203177  HUN      NaN    5.0  False     NaN
# 203178  HUN  Hungary    4.0  False     NaN
# 217586  GRE   Athens    NaN  False     NaN
# 217587  GRE   Athens    NaN  False     NaN
# 271490  SWE      NaN   13.0  False     NaN
#
# [308408 rows x 11 columns]

# %%
# Sorts by year, then sorts by medal when rows have the same year
resultsCSV.sort_values(['year', 'medal'])
# Out:
#           year    type              discipline  \
# 563     1896.0  Summer                  Tennis
# 672     1896.0  Summer                  Tennis
# 1527    1896.0  Summer               Athletics
# 24253   1896.0  Summer  Cycling Road (Cycling)
# 25815   1896.0  Summer  Cycling Road (Cycling)
# ...        ...     ...                     ...
# 203177     NaN     NaN                 Fencing
# 203178     NaN     NaN                 Fencing
# 217586     NaN     NaN     Football (Football)
# 217587     NaN     NaN     Football (Football)
# 271490     NaN     NaN       Diving (Aquatics)
#
#                                        event                     as  \
# 563                   Singles, Men (Olympic)  Konstantinos Paspatis
# 672                   Singles, Men (Olympic)    Momcsilló Tapavicza
# 1527                  Doubles, Men (Olympic)            Teddy Flack
# 24253   Road Race, Individual, Men (Olympic)          Edward Battel
# 25815                  Sprint, Men (Olympic)           Léon Flameng
# ...                                      ...                    ...
# 203177      Sabre, Individual, Men (Olympic)        Lóránt Mészáros
# 203178            Sabre, Team, Men (Olympic)        Lóránt Mészáros
# 217586          Football, Men (Intercalated)        Georgios Pantos
# 217587          Football, Men (Intercalated)   Alexandros Kalafatis
# 271490          Platform, Men (Intercalated)       Wilhelm Lindgren
#
#         athlete_id  noc                     team  place   tied   medal
# 563            181  GRE                      NaN    3.0   True  Bronze
# 672            226  HUN                      NaN    3.0   True  Bronze
# 1527           627  AUS  George Stuart Robertson    3.0  False  Bronze
# 24253        13526  GBR                      NaN    3.0  False  Bronze
# 25815        14328  FRA                      NaN    3.0  False  Bronze
# ...            ...  ...                      ...    ...    ...     ...
# 203177       95189  HUN                      NaN    5.0  False     NaN
# 203178       95189  HUN                  Hungary    4.0  False     NaN
# 217586      100811  GRE                   Athens    NaN  False     NaN
# 217587      100812  GRE                   Athens    NaN  False     NaN
# 271490      127259  SWE                      NaN   13.0  False     NaN
#
# [308408 rows x 11 columns]

# %%
# Sorts by year in ascending order then by medal in the opposite of alphabetical order
resultsCSV.sort_values(['year', 'medal'], ascending=[1,0])
# Out:
#           year    type              discipline  \
# 548     1896.0  Summer                  Tennis
# 549     1896.0  Summer                  Tennis
# 566     1896.0  Summer                  Tennis
# 25817   1896.0  Summer  Cycling Road (Cycling)
# 26340   1896.0  Summer  Cycling Road (Cycling)
# ...        ...     ...                     ...
# 203177     NaN     NaN                 Fencing
# 203178     NaN     NaN                 Fencing
# 217586     NaN     NaN     Football (Football)
# 217587     NaN     NaN     Football (Football)
# 271490     NaN     NaN       Diving (Aquatics)
#
#                                        event                       as  \
# 548                   Singles, Men (Olympic)       Demetrius Casdagli
# 549                   Doubles, Men (Olympic)       Demetrius Casdagli
# 566                   Doubles, Men (Olympic)  Dimitrios Petrokokkinos
# 25817           10,000 metres, Men (Olympic)             Léon Flameng
# 26340   Road Race, Individual, Men (Olympic)            Anton Gödrich
# ...                                      ...                      ...
# 203177      Sabre, Individual, Men (Olympic)          Lóránt Mészáros
# 203178            Sabre, Team, Men (Olympic)          Lóránt Mészáros
# 217586          Football, Men (Intercalated)          Georgios Pantos
# 217587          Football, Men (Intercalated)     Alexandros Kalafatis
# 271490          Platform, Men (Intercalated)         Wilhelm Lindgren
#
#         athlete_id  noc                     team  place   tied   medal
# 548            178  GRE                      NaN    2.0  False  Silver
# 549            178  GRE  Dimitrios Petrokokkinos    2.0  False  Silver
# 566            182  GRE       Demetrius Casdagli    2.0  False  Silver
# 25817        14328  FRA                      NaN    2.0  False  Silver
# 26340        14614  GER                      NaN    2.0  False  Silver
# ...            ...  ...                      ...    ...    ...     ...
# 203177       95189  HUN                      NaN    5.0  False     NaN
# 203178       95189  HUN                  Hungary    4.0  False     NaN
# 217586      100811  GRE                   Athens    NaN  False     NaN
# 217587      100812  GRE                   Athens    NaN  False     NaN
# 271490      127259  SWE                      NaN   13.0  False     NaN
#
# [308408 rows x 11 columns]

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# Data in a DataFrame can be filtered using the locator syntax.

# %%
bios = pd.read_csv('./data/bios.csv')
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
# Filter data and retrieve all columns
bios[bios['height_cm'] < 170]
# Out:
#         athlete_id                 name   born_date        born_city  \
# 3                4      Jacques Brugnon  1895-05-11      Paris VIIIe
# 14              15          Damien Éloi  1969-07-04             Vire
# 49              50       Gillian Gowers  1964-04-09              NaN
# 53              54          Andrea Holt  1970-11-11        Radcliffe
# 57              58           Lisa Lomas  1967-03-09        Dunstable
# ...            ...                  ...         ...              ...
# 145474      149201    Nadine Hofstetter  1994-10-21           Romoos
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 3             Paris          FRA         France      168.0       64.0
# 14         Calvados          FRA         France      165.0       58.0
# 49              NaN          NaN  Great Britain      157.0       55.0
# 53          England          GBR  Great Britain      168.0       64.0
# 57          England          GBR  Great Britain      168.0       63.0
# ...             ...          ...            ...        ...        ...
# 145474       Luzern          SUI    Switzerland      164.0       68.0
# 145495   Sverdlovsk          RUS            ROC      167.0       61.0
# 145496       Moskva          RUS            ROC      168.0       65.0
# 145497  Arkhangelsk          RUS            ROC      163.0       55.0
# 145498  Deux-Sèvres          FRA         France      166.0        NaN
#
#          died_date
# 3       1978-03-20
# 14             NaN
# 49             NaN
# 53             NaN
# 57             NaN
# ...            ...
# 145474         NaN
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
#
# [26642 rows x 10 columns]

# %%
# Filter data and retrieve specific columns
bios[bios['height_cm'] < 170][['name', 'born_city']]
# Out:
#                        name        born_city
# 3           Jacques Brugnon      Paris VIIIe
# 14              Damien Éloi             Vire
# 49           Gillian Gowers              NaN
# 53              Andrea Holt        Radcliffe
# 57               Lisa Lomas        Dunstable
# ...                     ...              ...
# 145474    Nadine Hofstetter           Romoos
# 145495    Polina Luchnikova            Serov
# 145496  Valeriya Merkusheva  Moskva (Moscow)
# 145497      Yuliya Smirnova           Kotlas
# 145498       André Foussard            Niort
#
# [26642 rows x 2 columns]

# %%
# Data can be filtered with multiple conditions using brackets
bios[(bios['height_cm'] < 170) & (bios['weight_kg'] < 60)][['name', 'born_country']]
# Out:
#                      name born_country
# 14            Damien Éloi          FRA
# 49         Gillian Gowers          NaN
# 62          Jo Muggeridge          GBR
# 128            Olga Nemes          ROU
# 134       Karen Stechmann          GER
# ...                   ...          ...
# 144766     Lara Della Mea          ITA
# 144796   Sofia Belingheri          ITA
# 145054  Svetlana Mironova          RUS
# 145055  Kristina Reztsova          RUS
# 145497    Yuliya Smirnova          RUS
#
# [15520 rows x 2 columns]

# %% [markdown]
# Data can also be filtered using the `.query()` function.

# %%
bios.query('born_country == "GBR" and born_city == "London"')
# Out:
#         athlete_id                name   born_date born_city born_region  \
# 62              63       Jo Muggeridge  1969-04-03    London     England
# 63              64        Mabel Parton  1881-07-22    London     England
# 110            111        Nick Ponting  1966-09-13    London     England
# 568            570      Mark Blenkarne  1957-10-07    London     England
# 1708          1715       Mark Hulstrøm  1965-12-28    London     England
# ...            ...                 ...         ...       ...         ...
# 141662      145238        Prisca Awiti  1996-02-20    London     England
# 142204      145805     Matthew Garbett  2002-04-13    London     England
# 143563      147216         Alie Rusher  1996-05-24    London     England
# 144063      147729    Lotte Wubben-Moy  1999-01-11    London     England
# 144811      148512  Benjamin Alexander  1983-05-08    London     England
#
#        born_country            NOC  height_cm  weight_kg   died_date
# 62              GBR  Great Britain      157.0       59.0         NaN
# 63              GBR  Great Britain        NaN        NaN  1962-08-12
# 110             GBR  Great Britain      173.0       76.0         NaN
# 568             GBR  Great Britain      183.0       70.0         NaN
# 1708            GBR        Denmark      181.0       92.0         NaN
# ...             ...            ...        ...        ...         ...
# 141662          GBR         Mexico        NaN        NaN         NaN
# 142204          GBR    New Zealand        NaN        NaN         NaN
# 143563          GBR  United States      185.0       70.0         NaN
# 144063          GBR  Great Britain        NaN        NaN         NaN
# 144811          GBR        Jamaica        NaN        NaN         NaN
#
# [317 rows x 10 columns]

# %% [markdown]
# Data can also be filtered using strings and regular expressions.

# %%
# Filter out names containing no
bios[bios["name"].str.contains("no", case=False)]
# Out:
#         athlete_id                name   born_date              born_city  \
# 3                4     Jacques Brugnon  1895-05-11            Paris VIIIe
# 101            102  Algernon Kingscote  1888-02-03  Bengaluru (Bangalore)
# 102            103       Peter Knowles  1969-12-28              Stockport
# 108            109       Arthur Norris         NaN                    NaN
# 117            118       Noel Turnbull  1890-12-20               Highgate
# ...            ...                 ...         ...                    ...
# 145358      149081        Novie McCabe  2001-12-15               Winthrop
# 145400      149123      Kenny Agostino  1992-04-30             Morristown
# 145403      149126          Noah Cates  1999-02-05             Stillwater
# 145451      149176         Tereza Nová  1998-02-06                   Stod
# 145497      149224     Yuliya Smirnova  1998-05-08                 Kotlas
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 3               Paris          FRA         France      168.0       64.0
# 101         Karnataka          IND  Great Britain        NaN        NaN
# 102           England          GBR  Great Britain      177.0       77.0
# 108               NaN          NaN  Great Britain        NaN        NaN
# 117           England          GBR  Great Britain        NaN        NaN
# ...               ...          ...            ...        ...        ...
# 145358     Washington          USA  United States        NaN        NaN
# 145400     New Jersey          USA  United States        NaN        NaN
# 145403      Minnesota          USA  United States        NaN        NaN
# 145451  Plzeňský kraj          CZE        Czechia        NaN        NaN
# 145497    Arkhangelsk          RUS            ROC      163.0       55.0
#
#          died_date
# 3       1978-03-20
# 101     1964-12-21
# 102            NaN
# 108            NaN
# 117     1970-12-17
# ...            ...
# 145358         NaN
# 145400         NaN
# 145403         NaN
# 145451         NaN
# 145497         NaN
#
# [6659 rows x 10 columns]

# %%
# Filter out names containing ca and no
bios[bios["name"].str.contains("ca||no", case=False)]
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %% [markdown]
# ## Modifying a DataFrame

# %% [markdown]
# ### Adding and Removing Columns

# %% [markdown]
# #### New Data

# %% [markdown]
# Adding a new column containing a single value at the end of the DataFrame can be done through the locator parameter.

# %%
coffee = pd.read_csv("./warmup-data/coffee.csv")
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee["price"] = 4.99
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   4.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   4.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   4.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %% [markdown]
# To add a column at the end of a DataFrame with multiple values, conditionals can be used via NumPy.

# %%
import numpy as np

# The 1st argument is the conditional, the 2nd is the value should conditional be true, the 3rs is the value should conditional be false
coffee["price"] = np.where(coffee["Coffee Type"]=="Espresso", 3.99, 5.99)
coffee
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   3.99
# 1      Monday       Latte          15   5.99
# 2     Tuesday    Espresso          30   3.99
# 3     Tuesday       Latte          20   5.99
# 4   Wednesday    Espresso          35   3.99
# 5   Wednesday       Latte          25   5.99
# 6    Thursday    Espresso          40   3.99
# 7    Thursday       Latte          30   5.99
# 8      Friday    Espresso          45   3.99
# 9      Friday       Latte          35   5.99
# 10   Saturday    Espresso          45   3.99
# 11   Saturday       Latte          35   5.99
# 12     Sunday    Espresso          45   3.99
# 13     Sunday       Latte          35   5.99

# %% [markdown]
# Columns can be removed using the `drop()` function or using the locator function.

# %%
# Return modified DataFrame without altering the original
coffee.drop(columns=['price'])

# Return modified DataFrame and alter the original
# Option 1: coffee.drop(columns=['price'], inplace=True)
# Option 2: coffee = coffee.drop([columns=['price'])
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %% [markdown]
# Columns can also be removed by specifying which columns you would like to keep with the location parameter.

# %%
coffee = coffee[['Day', 'Coffee Type']]
coffee
# Out:
#           Day Coffee Type
# 0      Monday    Espresso
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso
# 13     Sunday       Latte

# %% [markdown]
# #### Existing Data

# %% [markdown]
# New columns can be created using existing data already in the DataFrame.
#
# String operations can be performed, for example.

# %%
bios_new = bios.copy()

bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name
# 0       1960-10-02  Jean-François
# 1              NaN         Arnaud
# 2       1994-07-17           Jean
# 3       1978-03-20        Jacques
# 4       1930-07-25         Albert
# ...            ...            ...
# 145495         NaN         Polina
# 145496         NaN       Valeriya
# 145497         NaN         Yuliya
# 145498  1986-03-18          André
# 145499  2003-10-20           Bill
#
# [145500 rows x 11 columns]

# %% [markdown]
# Mathematical operations can also be performed.

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['price']
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %% [markdown]
# Functions, including lambda operations, can also be performed to produce columns from existing data.

# %%
# Create columns categorising people as Short, Average or Tall depending on their height

bios['height_category'] = bios['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall'))
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date height_category
# 0       1960-10-02            Tall
# 1              NaN         Average
# 2       1994-07-17         Average
# 3       1978-03-20         Average
# 4       1930-07-25            Tall
# ...            ...             ...
# 145495         NaN         Average
# 145496         NaN         Average
# 145497         NaN           Short
# 145498  1986-03-18         Average
# 145499  2003-10-20            Tall
#
# [145500 rows x 11 columns]

# %%
# Create columns based on a predefined function

def weight_class(rows):
    if rows['weight_kg'] < 50:
        return 'Underweight'
    elif 50 <= rows['weight_kg'] <= 100:
        return 'Average'
    else:
        return 'Overweight'

# Axis=1 will iterate by rows, axis=0 will iterate by columns
bios['weight_category'] = bios.apply(weight_class, axis=1)
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date height_category weight_category
# 0       1960-10-02            Tall      Overweight
# 1              NaN         Average         Average
# 2       1994-07-17         Average         Average
# 3       1978-03-20         Average         Average
# 4       1930-07-25            Tall      Overweight
# ...            ...             ...             ...
# 145495         NaN         Average         Average
# 145496         NaN         Average         Average
# 145497         NaN           Short         Average
# 145498  1986-03-18         Average      Overweight
# 145499  2003-10-20            Tall      Overweight
#
# [145500 rows x 12 columns]

# %% [markdown]
# ### Renaming Columns

# %% [markdown]
# The `.rename()` function is used to rename columns.

# %%
# A dictionary is used as the argument to the rename() function
coffee = coffee.rename(columns={'price':'new_price'})
coffee
# Out:
#           Day Coffee Type  new_price
# 0      Monday    Espresso       3.99
# 1      Monday       Latte       5.99
# 2     Tuesday    Espresso       3.99
# 3     Tuesday       Latte       5.99
# 4   Wednesday    Espresso       3.99
# 5   Wednesday       Latte       5.99
# 6    Thursday    Espresso       3.99
# 7    Thursday       Latte       5.99
# 8      Friday    Espresso       3.99
# 9      Friday       Latte       5.99
# 10   Saturday    Espresso       3.99
# 11   Saturday       Latte       5.99
# 12     Sunday    Espresso       3.99
# 13     Sunday       Latte       5.99

# %% [markdown]
# ### Changing Data Types
#
# Data types can be changed within a DataFrame, for example, to `datetime`, allowing for useful functionality.
#
# Tip: here is a datetime cheat sheet for Python https://strftime.org/.

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
# The format= argument allows to explocitly state the date and time format to convert to

bios['born_datetime'] = pd.to_datetime(bios['born_date'], format='%Y-%m-%d')
bios['born_year'] = bios['born_datetime'].dt.year
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date born_datetime  born_year
# 0       1960-10-02    1886-12-12     1886.0
# 1              NaN    1969-04-01     1969.0
# 2       1994-07-17    1898-08-13     1898.0
# 3       1978-03-20    1895-05-11     1895.0
# 4       1930-07-25    1878-04-17     1878.0
# ...            ...           ...        ...
# 145495         NaN    2002-01-30     2002.0
# 145496         NaN    1999-09-20     1999.0
# 145497         NaN    1998-05-08     1998.0
# 145498  1986-03-18    1899-05-19     1899.0
# 145499  2003-10-20    1913-07-15     1913.0
#
# [145500 rows x 12 columns]

# %% [markdown]
# ### Merging DataFrames
#
# Two DataFrames can be merged one after the other using the `.concat()` function.

# %%
bios = pd.read_csv('./data/bios.csv')
results = pd.read_csv('./data/results.csv')

bios_and_results = pd.concat([bios, results])
bios_and_results

# Note, this does not combine each row based on the athlete, simply just adds the rows on top of one another
# Out:
#         athlete_id                   name   born_date    born_city  \
# 0                1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01       Meulan
# 2                3           Jean Borotra  1898-08-13     Biarritz
# 3                4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4                5           Albert Canet  1878-04-17   Wandsworth
# ...            ...                    ...         ...          ...
# 308403      148983                    NaN         NaN          NaN
# 308404      148984                    NaN         NaN          NaN
# 308405      148985                    NaN         NaN          NaN
# 308406      148985                    NaN         NaN          NaN
# 308407      148986                    NaN         NaN          NaN
#
#                  born_region born_country     NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA  France        NaN        NaN
# 1                   Yvelines          FRA  France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                      Paris          FRA  France      168.0       64.0
# 4                    England          GBR  France        NaN        NaN
# ...                      ...          ...     ...        ...        ...
# 308403                   NaN          NaN     NaN        NaN        NaN
# 308404                   NaN          NaN     NaN        NaN        NaN
# 308405                   NaN          NaN     NaN        NaN        NaN
# 308406                   NaN          NaN     NaN        NaN        NaN
# 308407                   NaN          NaN     NaN        NaN        NaN
#
#          died_date    year    type              discipline  \
# 0       1960-10-02     NaN     NaN                     NaN
# 1              NaN     NaN     NaN                     NaN
# 2       1994-07-17     NaN     NaN                     NaN
# 3       1978-03-20     NaN     NaN                     NaN
# 4       1930-07-25     NaN     NaN                     NaN
# ...            ...     ...     ...                     ...
# 308403         NaN  2022.0  Winter                    Luge
# 308404         NaN  2022.0  Winter  Alpine Skiing (Skiing)
# 308405         NaN  2022.0  Winter  Alpine Skiing (Skiing)
# 308406         NaN  2022.0  Winter  Alpine Skiing (Skiing)
# 308407         NaN  2022.0  Winter                     NaN
#
#                                 event                    as  noc    team  \
# 0                                 NaN                   NaN  NaN     NaN
# 1                                 NaN                   NaN  NaN     NaN
# 2                                 NaN                   NaN  NaN     NaN
# 3                                 NaN                   NaN  NaN     NaN
# 4                                 NaN                   NaN  NaN     NaN
# ...                               ...                   ...  ...     ...
# 308403         Singles, Men (Olympic)         Marián Skupek  SVK     NaN
# 308404        Slalom, Women (Olympic)         Elsa Fermbäck  SWE     NaN
# 308405          Team, Mixed (Olympic)         Hilma Lövblom  SWE  Sweden
# 308406  Giant Slalom, Women (Olympic)         Hilma Lövblom  SWE     NaN
# 308407        Slalom, Women (Olympic)  Charlotta Säfvenberg  NaN     NaN
#
#         place   tied medal
# 0         NaN    NaN   NaN
# 1         NaN    NaN   NaN
# 2         NaN    NaN   NaN
# 3         NaN    NaN   NaN
# 4         NaN    NaN   NaN
# ...       ...    ...   ...
# 308403   26.0  False   NaN
# 308404   28.0  False   NaN
# 308405   13.0  False   NaN
# 308406    NaN  False   NaN
# 308407   24.0  False   NaN
#
# [453908 rows x 20 columns]

# %% [markdown]
# DataFrames can also be combined in such a way that the data for 1 row is combined with the data from another based on a common identifier.

# %%
combined_df = pd.merge(results, bios, on='athlete_id', how='left')
combined_df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA              NaN   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA              NaN   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 308403          Marián Skupek      148983  SVK              NaN   26.0  False
# 308404          Elsa Fermbäck      148984  SWE              NaN   28.0  False
# 308405          Hilma Lövblom      148985  SWE           Sweden   13.0  False
# 308406          Hilma Lövblom      148985  SWE              NaN    NaN  False
# 308407   Charlotta Säfvenberg      148986  NaN              NaN   24.0  False
#
#        medal                   name   born_date   born_city born_region  \
# 0        NaN  Jean-François Blanchy  1886-12-12    Bordeaux     Gironde
# 1        NaN  Jean-François Blanchy  1886-12-12    Bordeaux     Gironde
# 2        NaN  Jean-François Blanchy  1886-12-12    Bordeaux     Gironde
# 3        NaN  Jean-François Blanchy  1886-12-12    Bordeaux     Gironde
# 4        NaN  Jean-François Blanchy  1886-12-12    Bordeaux     Gironde
# ...      ...                    ...         ...         ...         ...
# 308403   NaN          Marián Skupek  2001-07-12     Gelnica      Košice
# 308404   NaN          Elsa Fermbäck  1998-03-28    Vemdalen    Jämtland
# 308405   NaN          Hilma Lövblom  2000-08-16        Täby   Stockholm
# 308406   NaN          Hilma Lövblom  2000-08-16        Täby   Stockholm
# 308407   NaN   Charlotta Säfvenberg  1994-10-07  Kungsbacka     Halland
#
#        born_country       NOC  height_cm  weight_kg   died_date
# 0               FRA    France        NaN        NaN  1960-10-02
# 1               FRA    France        NaN        NaN  1960-10-02
# 2               FRA    France        NaN        NaN  1960-10-02
# 3               FRA    France        NaN        NaN  1960-10-02
# 4               FRA    France        NaN        NaN  1960-10-02
# ...             ...       ...        ...        ...         ...
# 308403          SVK  Slovakia      196.0      108.0         NaN
# 308404          SWE    Sweden        NaN        NaN         NaN
# 308405          SWE    Sweden        NaN        NaN         NaN
# 308406          SWE    Sweden        NaN        NaN         NaN
# 308407          SWE    Sweden        NaN        NaN         NaN
#
# [308408 rows x 20 columns]
